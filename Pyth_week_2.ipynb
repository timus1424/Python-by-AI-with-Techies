# %% [markdown]
# <a href="https://colab.research.google.com/github/timus1424/Python-by-AI-with-Techies/blob/main/Pyth_week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#code written by aarushi

a=int(input("enter 1st number"))
b=int(input("enter 2nd number"))
if(a<b):
  print("b is greater than a")
else:
  print("a is greater than b")
# Out:
# enter 1st number20
# enter 2nd number11
# a is greater than b

# %% [markdown]
# #**Day 8**
#
# #Functions
#
# input, logic, output
#
# 1. Defining a function:
# def functionName():
#
# 2. Calling a function:
# functionName()
#
# **Parameterised Functiond/Params**
#
# *f"string{variableName}": *

# %%
def hello(name):
  print(f"Hello {name}!")

# %%
hello("Diya")
# Out:
# Hello Diya!

# %%
#function to add two numbers

def addition(a, b):
  c = a + b
  print("Addition:", c)

#addition(4,5)

#function to return sum of two numbers
def add(x, y):
  z= x + y
  return z
s = add(7,93)

s
# Out:
# 100

# %% [markdown]
# #Day 9
#
# 3. Default Parameters
# 4. Keyword Arguments
# 5. Scope and Global Variables:
# global variables- define outside the function
# 6. Nested functions

# %%
def hello(name="Guest"):
  print(f"Hello {name}!")

hello()

hello("chérie")
# Out:
# Hello Guest!
# Hello chérie!

# %%
#function to return sum of two numbers
def add(x=10, y=6):
  z= x + y
  return z
s = add(7,93)
a = add()

print(s)
print(a)
# Out:
# 100
# 16

# %%
def fav_city(city, name):
  hello(name)
  print(f"Welcome to {city}!")

fav_city("Mumbai", "Diya•Sumit")
# Out:
# Hello Diya•Sumit!
# Welcome to Mumbai!

# %% [markdown]
# #Day 10
# **Working with Strings**
#
# 1. Creating a String
# 2. Accessing a String
# - similar to lists [index_position]
# 3. Slicing a String
# - again, same as lists;negative-indexing possible
# 4. String-concatenation: +
# 5. String Repetition: *
# 6. Length of a String: len()
# 7. Checking Substrings: in keyword
# 8. String Methods/Functions:
# - .lower()
# - .upper()
# - join
# - split
# - strip
# - replace

# %%
"Ha"*3 + "!"
# Out:
# 'HaHaHa!'

# %% [markdown]
# #Day 11
# **Error Handling in Python**
#
# *ERRORS*
# 1. Syntax Error:
# - print("Hello World"
# 2. Type Error:
# - 2 + 3 -> 5
# - 2 + "Hello" ->error
# 3. Name Error:
# - not defined
# 4. Index Error:
# - out of bound error while accesing elements in the list
# 5. Key Error:
# - d1={'k1':'v1'}=> d1['k1']->'v1'
# d1[k2]-> gives error (key missing)
# 6. Value Error:
# - int(9.8)=9 -> correct
# - int("Hello") -> incorrect
# 7. Zero Division Error
#
#
# *HANDLING*
# - lets you explain or handle the error and also continue the code.
#
# **try:**
#
#   *//body*
#
# **except:**
#
#   *//body*

# %%
# .txt file

# %%
# %%writefile my_file.txt
# This is a sample text file.
# It was created in Google Colab.
# Out:
# Writing my_file.txt

# %% [markdown]
# You can then verify the file's creation and content using shell commands like `!ls` and `!cat`.

# %%
# !ls
# !cat my_file.txt
# Out:
# my_file.txt  sample_data
# This is a sample text file.
# It was created in Google Colab.

# %%
with open('my_file.txt', 'a') as f:
  f.write('This is the third line.')

# %%
with open('my_file.txt', 'r') as f:
  print(f.read())
# Out:
# This is a sample text file.
# It was created in Google Colab.
# This is the third line.

# %%
# %%writefile my_csv_file.csv
# header1,header2
# value1_1,value1_2
# value2_1,value2_2
# Out:
# Writing my_csv_file.csv

# %%
import pandas as pd

# %%
pd.read_csv('my_csv_file.csv')
# Out:
#     header1   header2
# 0  value1_1  value1_2
# 1  value2_1  value2_2

# %% [markdown]
# #Weekly Project 02
# **Project Overview: Create a simple calculator that can perform basic arithmetic operations such as addition, subtraction, multiplication, and division. Each operation will be implemented as a separate function, and the user can choose which operation to perform. add(a, b) for addition subtract(a, b) for subtraction multiply(a, b) for multiplication divide(a, b) for division**

# %%
def add(a, b):
  return a + b

def subtract(a, b):
  return a - b

def multiply(a, b):
  return a * b

def divide(a, b):
#Handles division by zero
  if b == 0:
    return "Error: Cannot divide by zero!"
  return a / b

# %%
m = add(10, 5)
n = subtract(99, 43)
o = multiply(47, 54)
p = divide(9832, 4)
print(m,"\t", n, "\t", o, "\t", p)
# Out:
# 15 	 56 	 2538 	 2458.0

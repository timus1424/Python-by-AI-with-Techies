# %% [markdown]
# <a href="https://colab.research.google.com/github/timus1424/Python-by-AI-with-Techies/blob/main/Pyth_week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Day 1
# print(" " )
#
# #Day 2
#
# int
# float
# str
#
# comment: cmd+/
#
# x=1
# y=2
# z=3
#   ||
# x, y,z = 1, 2, 3
#
# #Day 3
# Run: cmd+enter
# Comparison: <, >, ==, <=, >=, !=
#
# if <condition>:
#   body
# elif<condition>:
#   body
# else:
#   body

# %%
# Out:
# Welcome to Tic-Tac-Toe!
#
# To make a move, enter a number from 1 to 9 corresponding to the board positions:
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 9
#
#
#   |   |
# ---------
#   |   |
# ---------
#   |   |
#
#
# Player X's turn.
# Enter your move (1-9): 1
#
#
# X |   |
# ---------
#   |   |
# ---------
#   |   |
#
#
# Player O's turn.
# Enter your move (1-9): 5
#
#
# X |   |
# ---------
#   | O |
# ---------
#   |   |
#
#
# Player X's turn.
# Enter your move (1-9): 3
#
#
# X |   | X
# ---------
#   | O |
# ---------
#   |   |
#
#
# Player O's turn.
# Enter your move (1-9): 2
#
#
# X | O | X
# ---------
#   | O |
# ---------
#   |   |
#
#
# Player X's turn.
# Enter your move (1-9): 8
#
#
# X | O | X
# ---------
#   | O |
# ---------
#   | X |
#
#
# Player O's turn.
# Enter your move (1-9): 4
#
#
# X | O | X
# ---------
# O | O |
# ---------
#   | X |
#
#
# Player X's turn.
# Enter your move (1-9): 9
#
#
# X | O | X
# ---------
# O | O |
# ---------
#   | X | X
#
# ...

# %% [markdown]
# #Day 4
# range(start, end)
#
# by default start=0, range(20) means 0 to 20;
# end=n-1
#
# / -> quotient
# % -> remainder

# %%
for i in range(1, 10):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# #Day 5
# Creating a List
#
# items[]
#
# **Slicing the list:**
# list_name[starting_index:ending_index+1]
#
# now if we have to print from beginning, you can just skip the starting_index
# i.e. items[:3]
# and if you want to print till the last element, you can just skip the ending_index
# i.e. items[2:]
#
# **Modyifying element in a list:**
# listName[n]='new_value'
#
# **Adding elements to the list:**
# listName.append('new_value')
#
# **Removing elemnts in a list:**
# • listName.remove('value') //delete a certain value whose index is not known
# • del listName[index] //delete from a index
# • listName.clear() //clear the list
#
# **Checking if a item exists:**
# print("value" in items) //in is a keyword

# %%
items=['hello', 'its', 'a', 'wonderful', 'day']
items[1]

print(items)

items[-1]
print(items[1:4])

print(items[2:-1])
# Out:
# ['hello', 'its', 'a', 'wonderful', 'day']
# ['its', 'a', 'wonderful']
# ['a', 'wonderful']

# %%
tech = ['computer', 'laptop', 'charger', 'speaker', 'mic', 'mobile']
tech.remove('mic')
print(tech)
tech.append("Microphone")
print(tech)
print('charger' in tech)
del tech[2]
print('charger' in tech)
print(tech)
tech.clear()
print(tech)
# Out:
# ['computer', 'laptop', 'charger', 'speaker', 'mobile']
# ['computer', 'laptop', 'charger', 'speaker', 'mobile', 'Microphone']
# True
# False
# ['computer', 'laptop', 'speaker', 'mobile', 'Microphone']
# []

# %% [markdown]
# #continuation of Day 5
#
# **Length of a list:**
# len(listName)
#
# **List comprehension**
# • for variable in listName:
#   print(operation)
# //operation here= i/2
#
# //new
# [operation for variable in listName]

# %%
len(items)

scores=[70, 35, 80, 60, 90]

for i in scores:
  print(i/2)

l=len(scores)
s= 0
j=0
for j in scores:
  s=s+j
print("\nAvg score:", s/l)

[i/2 for i in scores]

[i/3.33 for i in scores]
# Out:
# 35.0
# 17.5
# 40.0
# 30.0
# 45.0
#
# Avg score: 67.0
# [21.0, 10.5, 24.0, 18.0, 27.0]

# %% [markdown]
# ### Python Lists: Multiple Choice Questions
#
# 1.  Which of the following is the correct way to create an empty list in Python?
#     a)  `my_list = {}`
#     b)  `my_list = ()`
#     *c)  `my_list = []`*
#     d)  `my_list = new list()`
#
# 2.  Given the list `fruits = ['apple', 'banana', 'cherry']`, what is the output of `fruits[1]`?
#     a)  `'apple'`
#     *b)  `'banana'`*
#     c)  `'cherry'`
#     d)  `None`
#
# 3.  If `numbers = [10, 20, 30, 40, 50]`, what will `numbers[1:4]` return?
#     a)  `[10, 20, 30]`
#     *b)  `[20, 30, 40]`*
#     c)  `[10, 20, 30, 40]`
#     d)  `[20, 30, 40, 50]`
#
# 4.  To add an element `'orange'` to the end of the list `fruits = ['apple', 'banana']`, which method would you use?
#     a)  `fruits.insert('orange')`
#     b)  `fruits.add('orange')`
#     *c)  `fruits.append('orange')`*
#     d)  `fruits.extend('orange')`
#
# 5. What does `len(['a', 'b', 'c', 'd'])` return?
#     a)  `3`
#     *b)  `4`*
#     c)  `5`
#     d)  `Error`

# %% [markdown]
# ### More Challenging Python Lists MCQs
#
# 1.  What is the output of the following code snippet?*
#     ```python
#     list1 = [1, 2, 3]
#     list2 = [4, 5, 6]
#     list3 = list1 + list2
#     print(list3)
#     ```
#     a)  `[1, 2, 3, 4, 5, 6]`
#     *b)  `[1, 2, 3], [4, 5, 6]`*
#     c)  `[5, 7, 9]`
#     d)  `Error`
#
# 2.  Consider the list `my_list = [10, 20, 30, 40, 50]`. What will `my_list.pop(2)` return, and what will `my_list` look like after the operation?
#     *a)  Returns `30`, `my_list` is `[10, 20, 40, 50]`*
#     b)  Returns `30`, `my_list` is `[10, 20, 30, 40, 50]`
#     c)  Returns `40`, `my_list` is `[10, 20, 30, 50]`
#     d)  Returns `20`, `my_list` is `[10, 30, 40, 50]`
#
# 3.  What is the effect of `my_list = [1, 2, 3]; my_list.extend([4, 5])`?
#     a)  `my_list` becomes `[1, 2, 3, [4, 5]]`
#     b)  `my_list` becomes `[1, 2, 3, 4, 5]`
#     c)  `my_list` becomes `[4, 5, 1, 2, 3]`
#     d)  `my_list` remains `[1, 2, 3]`
#
# 4.  If `data = [[1, 2], [3, 4]]`, what is `data[0][1]`?
#     a)  `1`
#     b)  `2`
#     c)  `3`
#     d)  `[1, 2]`
#
# 5.  Which of the following statements about list copying is true?
#     a)  `list2 = list1` creates a completely independent copy of `list1`.
#     b)  `list2 = list1[:]` creates a shallow copy, meaning changes to nested lists in `list1` will not affect `list2`.
#     c)  `list2 = list(list1)` creates a shallow copy, meaning changes to nested lists in `list1` will affect `list2`.
#     d)  Using `copy.deepcopy(list1)` is necessary to ensure no elements in `list2` refer to the same objects as `list1`.

# %% [markdown]
# #WEEKLY PROJECT_01
#
# At the start of the day you have a checklist The tasks which you were able to finish, should get added to completed_tasks The tasks which you were not able to finish, should get added to incomplete_tasks This project is about organizing your daily tasks into two categories: completed tasks and incomplete tasks. Here’s how it works: 1. At the start of the day, you create a checklist of tasks you want to accomplish. 2. At the end of the day, you review which tasks you could finish and which you couldn’t. – If a task is finished, you move it to the completed tasks list. – If a task is not finished, you move it to the incomplete tasks list. This way, by the end of each day, you’ll have a clear overview of what you completed and what still needs attention.

# %%
completed_tasks = []
incomplete_tasks = []

# %%
#initialising
completed_tasks = []
incomplete_tasks = []

#creating tasks
daily_checklist = ['Freshen up', 'Breakfast', 'Study', 'Build', 'Lunch', 'Gym', 'Practise', 'Rest', 'Dinner', 'Sleep']
print("Your daily checklist:")
for task in daily_checklist:
    print(f"- {task}")
#checking if they have been carried out
for task in daily_checklist:
    print(f"\nTask: {task}")
    status= input("Enter 1 if task completed, else 0: ")

    # Convert the input string to an integer for comparison
    if int(status) == 1:
        completed_tasks.append(task)
    else:
        incomplete_tasks.append(task)
#displaying results
print("\n--- Daily Review Summary ---")
print("Completed Tasks:", completed_tasks)
print("Incomplete Tasks:", incomplete_tasks)
